# %% [markdown]
# # Industrial Alert Calibration: public benchmark runs
#
# This notebook attaches public MetroPT-3 and SWaT datasets, installs the public implementation, and writes resumable derived artifacts under `/kaggle/working/artifacts`. Raw input files are not republished.

# %%
# !git clone --depth 1 https://github.com/kushc2004/industrial-alert-calibration.git
# %pip install -q ./industrial-alert-calibration

# %%
# !industrial-alerts run '/kaggle/input/metropt-3-dataset/MetroPT3(AirCompressor).csv' --dataset metropt_raw --run-id metropt-conformal-v2 --artifacts-dir /kaggle/working/artifacts --alpha 0.01 --max-gap-steps 3 --min-event-points 2
from pathlib import Path
import subprocess

merged = Path('/kaggle/input/swat-dataset-secure-water-treatment-system/merged.csv')
if merged.exists():
    subprocess.run(['industrial-alerts', 'run', str(merged), '--dataset', 'swat', '--run-id', 'swat-conformal-v2', '--artifacts-dir', '/kaggle/working/artifacts', '--alpha', '0.01', '--max-gap-steps', '3', '--min-event-points', '2'], check=True)
else:
    print('SWaT skipped: attach vishala28/swat-dataset-secure-water-treatment-system.')

# %%
import json
from pathlib import Path

for path in sorted(Path('/kaggle/working/artifacts').glob('*/metrics.json')):
    print(path.parent.name)
    print(json.dumps(json.loads(path.read_text()), indent=2))
